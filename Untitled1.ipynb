# %%
import pandas as pd
import numpy as np

# %%
df =pd.DataFrame(np.arange (5,25).reshape(5,4),index=['Row1','Row2','Row3','Row4','Row5'])

# %%
df.head()
# Out:
#        0   1   2   3
# Row1   5   6   7   8
# Row2   9  10  11  12
# Row3  13  14  15  16
# Row4  17  18  19  20
# Row5  21  22  23  24

# %%
df.to_csv('sample.csv')

# %%
df.loc['Row1']
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# Name: Row1, dtype: int64

# %%
df.loc['Row2']
# Out:
# 0     9
# 1    10
# 2    11
# 3    12
# Name: Row2, dtype: int64

# %%
df.loc[['Row1','Row2']]
# Out:
#       0   1   2   3
# Row1  5   6   7   8
# Row2  9  10  11  12

# %%
type(df.loc['Row1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[ :,3:]
# Out:
#        3
# Row1   8
# Row2  12
# Row3  16
# Row4  20
# Row5  24

# %%
df.iloc [0:2,0:2]
# Out:
#       0   1
# Row1  5   6
# Row2  9  10
